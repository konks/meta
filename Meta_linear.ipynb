# %% [markdown]
# # Section 3.2. Meta in linear layer. Test 1

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torchsummary import summary
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision
import torchvision.transforms as transforms
import numpy as np
from sklearn.model_selection import train_test_split

from tqdm.notebook import tqdm
import torch.optim as optim
# !pip install torchmetrics
import torchmetrics

# %matplotlib inline

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# Requirement already satisfied: torchmetrics in c:\users\nikit\anaconda3_64\lib\site-packages (0.6.1)
# Requirement already satisfied: torch>=1.3.1 in c:\users\nikit\anaconda3_64\lib\site-packages (from torchmetrics) (1.7.0+cu101)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\nikit\anaconda3_64\lib\site-packages (from torchmetrics) (1.19.2)
# Requirement already satisfied: packaging in c:\users\nikit\anaconda3_64\lib\site-packages (from torchmetrics) (20.4)
# Requirement already satisfied: dataclasses in c:\users\nikit\anaconda3_64\lib\site-packages (from torch>=1.3.1->torchmetrics) (0.6)
# Requirement already satisfied: future in c:\users\nikit\anaconda3_64\lib\site-packages (from torch>=1.3.1->torchmetrics) (0.18.2)
# Requirement already satisfied: typing-extensions in c:\users\nikit\anaconda3_64\lib\site-packages (from torch>=1.3.1->torchmetrics) (3.7.4.3)
# Requirement already satisfied: six in c:\users\nikit\anaconda3_64\lib\site-packages (from packaging->torchmetrics) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nikit\anaconda3_64\lib\site-packages (from packaging->torchmetrics) (2.4.7)

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 128

trainset = torchvision.datasets.CIFAR10(root='cifar', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='cifar', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class Meta(nn.Module):
  def __init__(self, dim_in, dim_out):
    super().__init__()
    self.weight = nn.Parameter(torch.randn((dim_in, dim_out)))

  def forward(self, batch):
    weight = F.softmax(self.weight, 1)
    batch = batch @ self.weight
    return batch

# %%
class MyNet_Meta_linear_1(nn.Module):
  def __init__(self):
    super().__init__()
    self.input_filter = nn.Sequential(
        nn.Conv2d(3, 6, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(6),
        nn.Conv2d(6, 16, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(16),
        nn.MaxPool2d(2, 2), nn.Dropout2d(0.1),
    )
    self.hidden_filter = nn.Sequential(
        nn.Conv2d(16, 32, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(32),
        nn.MaxPool2d(2, 2), nn.Dropout2d(0.1),
    )
    self.linears = nn.ModuleList(
        [nn.Sequential(nn.Linear(8 * 8 * 8, 10), nn.PReLU(), nn.Dropout(0.1)) for i in range(4)]
    )
    self.meta = nn.Sequential(
        Meta(4, 4), nn.PReLU(),
    )
    self.out = nn.Linear(40, 10)
    
  def forward(self, batch):
    batch = self.input_filter(batch)
    batch = self.hidden_filter(batch)
    batch = batch.flatten(1)
    temp = []
    for i, linear in enumerate(self.linears):
      temp.append(linear(batch[:, i*batch.shape[1]//4 : (i+1)*batch.shape[1]//4]).unsqueeze(-1))
    batch = torch.cat(temp, axis=-1)
    batch = self.meta(batch)
    batch = batch.flatten(1)
    return self.out(batch)

# %%
net = MyNet_Meta_linear_1().to(device)
criterion = torch.nn.CrossEntropyLoss()
metric = torchmetrics.Accuracy().to(device)
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# %%
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 32, 32]             168
#              PReLU-2            [-1, 6, 32, 32]               1
#        BatchNorm2d-3            [-1, 6, 32, 32]              12
#             Conv2d-4           [-1, 16, 32, 32]             880
#              PReLU-5           [-1, 16, 32, 32]               1
#        BatchNorm2d-6           [-1, 16, 32, 32]              32
#          MaxPool2d-7           [-1, 16, 16, 16]               0
#          Dropout2d-8           [-1, 16, 16, 16]               0
#             Conv2d-9           [-1, 32, 16, 16]           4,640
#             PReLU-10           [-1, 32, 16, 16]               1
#       BatchNorm2d-11           [-1, 32, 16, 16]              64
#         MaxPool2d-12             [-1, 32, 8, 8]               0
#         Dropout2d-13             [-1, 32, 8, 8]               0
#            Linear-14                   [-1, 10]           5,130
#             PReLU-15                   [-1, 10]               1
#           Dropout-16                   [-1, 10]               0
#            Linear-17                   [-1, 10]           5,130
#             PReLU-18                   [-1, 10]               1
#           Dropout-19                   [-1, 10]               0
#            Linear-20                   [-1, 10]           5,130
#             PReLU-21                   [-1, 10]               1
#           Dropout-22                   [-1, 10]               0
#            Linear-23                   [-1, 10]           5,130
#             PReLU-24                   [-1, 10]               1
#           Dropout-25                   [-1, 10]               0
#              Meta-26                [-1, 10, 4]              16
#             PReLU-27                [-1, 10, 4]               1
#            Linear-28                   [-1, 10]             410
# ================================================================
# Total params: 26,750
# Trainable params: 26,750
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.80
# Params size (MB): 0.10
# Estimated Total Size (MB): 0.91
# ----------------------------------------------------------------

# %%
def train(model, trainloader, testloader, optimizer, criterion, metric, epochs = 10):
  history_loss = []
  history_metrics = []
  history_test_loss = []
  history_test_metrics = []

  for epoch in tqdm(range(epochs)):
    losss = []
    metrics = []
    test_loss = []
    test_metrics = []
    model.train()
    for batch, target in trainloader:
      batch = batch.to(device)
      target = target.to(device)
      optimizer.zero_grad()
      out = model(batch)
      loss = criterion(out, target)
      losss.append(loss.item())
      metrics.append(metric(out, target).item())

      loss.backward()
      optimizer.step()

    model.eval()
    for batch, target in testloader:
      batch = batch.to(device)
      target = target.to(device)
      out = model(batch)
      loss = criterion(out, target)
      test_loss.append(loss.item())
      test_metrics.append(metric(out, target).item())

    history_loss.append(np.mean(losss))
    history_metrics.append(np.mean(metrics))
    history_test_loss.append(np.mean(test_loss))
    history_test_metrics.append(np.mean(test_metrics))
  
  return   history_loss, history_metrics, history_test_loss, history_test_metrics

# %%
epochs = 20
history_loss, history_metrics, history_test_loss, history_test_metrics = train(net, trainloader, testloader, optimizer, criterion, metric, epochs=epochs)

print("Обучение завершено")
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].set_title("Losses")
ax[0].plot(history_loss, label="train")
ax[0].plot(history_test_loss, label="test")
ax[0].legend()
ax[0].hlines(np.linspace(0, np.max(history_test_loss), epochs), xmin=0, xmax=epochs-1, colors='black', alpha=0.3, linestyles="--", lw=0.5)

ax[1].set_title("Accuracy")
ax[1].plot(history_metrics, label="train")
ax[1].plot(history_test_metrics, label="test")
ax[1].legend()
ax[1].hlines(np.linspace(0, 1, 10), xmin=0, xmax=epochs-1, colors='black', alpha=0.3, linestyles="--", lw=0.5)

print("Best accuracy:",  np.max(history_test_metrics))
plt.show()
# Out:
# Обучение завершено
# Best accuracy: 0.7198378164556962

# %% [markdown]
# # Section 3.2. Meta in linear layer. Test 2

# %%
class MyNet_Meta_linear_2(nn.Module):
  def __init__(self):
    super().__init__()
    self.input_filter = nn.Sequential(
        nn.Conv2d(3, 16, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(16),
        nn.Conv2d(16, 32, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(32),
        nn.MaxPool2d(2, 2), nn.Dropout2d(0.1),
        nn.Conv2d(32, 64, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(64),
    )

    self.hidden_filter1 = nn.Sequential(
        nn.Conv2d(64, 64, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(64),
        nn.MaxPool2d(2, 2), nn.Dropout2d(0.1),
    )
    self.hidden_filter2 = nn.Sequential(
        nn.Conv2d(64, 128, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(128),
    )
    self.hidden_filter3 = nn.Sequential(
        nn.Conv2d(128, 128, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(128),
        nn.AdaptiveAvgPool2d((3, 3)), nn.Dropout2d(0.1),
    )

    self.linears = nn.ModuleList(
        [nn.Sequential(nn.Linear(8 * 3 * 3, 8), nn.PReLU(), nn.Dropout(0.1)) for i in range(16)]
    )
    self.meta = nn.Sequential(
        Meta(16, 8), nn.PReLU(),
    )
    self.out = nn.Linear(64, 10)
    
  def forward(self, batch):
    batch = self.input_filter(batch)
    batch = self.hidden_filter1(batch)
    batch = self.hidden_filter2(batch)
    batch = self.hidden_filter3(batch)
    batch = batch.flatten(1)
    temp = []
    for i, linear in enumerate(self.linears):
      temp.append(linear(batch[:, i*batch.shape[1]//16 : (i+1)*batch.shape[1]//16]).unsqueeze(-1))
    batch = torch.cat(temp, axis=-1)
    batch = self.meta(batch)
    batch = batch.flatten(1)
    return self.out(batch)

# %%
net = MyNet_Meta_linear_2().to(device)
criterion = torch.nn.CrossEntropyLoss()
metric = torchmetrics.Accuracy().to(device)
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# %%
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#              PReLU-2           [-1, 16, 32, 32]               1
#        BatchNorm2d-3           [-1, 16, 32, 32]              32
#             Conv2d-4           [-1, 32, 32, 32]           4,640
#              PReLU-5           [-1, 32, 32, 32]               1
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#          MaxPool2d-7           [-1, 32, 16, 16]               0
#          Dropout2d-8           [-1, 32, 16, 16]               0
#             Conv2d-9           [-1, 64, 16, 16]          18,496
#             PReLU-10           [-1, 64, 16, 16]               1
#       BatchNorm2d-11           [-1, 64, 16, 16]             128
#            Conv2d-12           [-1, 64, 16, 16]          36,928
#             PReLU-13           [-1, 64, 16, 16]               1
#       BatchNorm2d-14           [-1, 64, 16, 16]             128
#         MaxPool2d-15             [-1, 64, 8, 8]               0
#         Dropout2d-16             [-1, 64, 8, 8]               0
#            Conv2d-17            [-1, 128, 8, 8]          73,856
#             PReLU-18            [-1, 128, 8, 8]               1
#       BatchNorm2d-19            [-1, 128, 8, 8]             256
#            Conv2d-20            [-1, 128, 8, 8]         147,584
#             PReLU-21            [-1, 128, 8, 8]               1
#       BatchNorm2d-22            [-1, 128, 8, 8]             256
# AdaptiveAvgPool2d-23            [-1, 128, 3, 3]               0
#         Dropout2d-24            [-1, 128, 3, 3]               0
#            Linear-25                    [-1, 8]             584
#             PReLU-26                    [-1, 8]               1
#           Dropout-27                    [-1, 8]               0
#            Linear-28                    [-1, 8]             584
#             PReLU-29                    [-1, 8]               1
#           Dropout-30                    [-1, 8]               0
#            Linear-31                    [-1, 8]             584
#             PReLU-32                    [-1, 8]               1
#           Dropout-33                    [-1, 8]               0
#            Linear-34                    [-1, 8]             584
#             PReLU-35                    [-1, 8]               1
#           Dropout-36                    [-1, 8]               0
#            Linear-37                    [-1, 8]             584
#             PReLU-38                    [-1, 8]               1
#           Dropout-39                    [-1, 8]               0
#            Linear-40                    [-1, 8]             584
#             PReLU-41                    [-1, 8]               1
#           Dropout-42                    [-1, 8]               0
#            Linear-43                    [-1, 8]             584
#             PReLU-44                    [-1, 8]               1
#           Dropout-45                    [-1, 8]               0
#            Linear-46                    [-1, 8]             584
#             PReLU-47                    [-1, 8]               1
#           Dropout-48                    [-1, 8]               0
#            Linear-49                    [-1, 8]             584
#             PReLU-50                    [-1, 8]               1
#           Dropout-51                    [-1, 8]               0
#            Linear-52                    [-1, 8]             584
#             PReLU-53                    [-1, 8]               1
#           Dropout-54                    [-1, 8]               0
#            Linear-55                    [-1, 8]             584
#             PReLU-56                    [-1, 8]               1
#           Dropout-57                    [-1, 8]               0
#            Linear-58                    [-1, 8]             584
#             PReLU-59                    [-1, 8]               1
#           Dropout-60                    [-1, 8]               0
#            Linear-61                    [-1, 8]             584
#             PReLU-62                    [-1, 8]               1
#           Dropout-63                    [-1, 8]               0
#            Linear-64                    [-1, 8]             584
#             PReLU-65                    [-1, 8]               1
#           Dropout-66                    [-1, 8]               0
#            Linear-67                    [-1, 8]             584
#             PReLU-68                    [-1, 8]               1
#           Dropout-69                    [-1, 8]               0
#            Linear-70                    [-1, 8]             584
#             PReLU-71                    [-1, 8]               1
#           Dropout-72                    [-1, 8]               0
#              Meta-73                 [-1, 8, 8]             128
#             PReLU-74                 [-1, 8, 8]               1
#            Linear-75                   [-1, 10]             650
# ================================================================
# Total params: 292,961
# Trainable params: 292,961
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.46
# Params size (MB): 1.12
# Estimated Total Size (MB): 3.59
# ----------------------------------------------------------------

# %%
epochs = 20
history_loss, history_metrics, history_test_loss, history_test_metrics = train(net, trainloader, testloader, optimizer, criterion, metric, epochs=epochs)

print("Обучение завершено")
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].set_title("Losses")
ax[0].plot(history_loss, label="train")
ax[0].plot(history_test_loss, label="test")
ax[0].legend()
ax[0].hlines(np.linspace(0, np.max(history_test_loss), epochs), xmin=0, xmax=epochs-1, colors='black', alpha=0.3, linestyles="--", lw=0.5)

ax[1].set_title("Accuracy")
ax[1].plot(history_metrics, label="train")
ax[1].plot(history_test_metrics, label="test")
ax[1].legend()
ax[1].hlines(np.linspace(0, 1, 10), xmin=0, xmax=epochs-1, colors='black', alpha=0.3, linestyles="--", lw=0.5)

print("Best accuracy:",  np.max(history_test_metrics))
plt.show()
# Out:
# Обучение завершено
# Best accuracy: 0.8424643987341772

# %% [markdown]
# # Section 3.2. Meta in linear layer. Test 3

# %%
class ResUnit(nn.Module):
  def __init__(self, dim):
    super().__init__()
    self.step1 = nn.Sequential(
        nn.Conv2d(dim, dim, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(dim),
    )
    self.step2 = nn.Sequential(
        nn.Conv2d(dim, dim, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(dim), nn.Dropout2d(0.1)
    )

  def forward(self, batch):
    batch = self.step1(batch)
    return self.step2(batch)

class ResBlock(nn.Module):
  def __init__(self, dim):
    super().__init__()
    self.step = ResUnit(dim)

  def forward(self, batch):
    return batch + self.step(batch)

# %%
class MyNet_Meta_linear_3(nn.Module):
  def __init__(self):
    super().__init__()
    self.input_filter = nn.Sequential(
        nn.Conv2d(3, 16, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(16),
        nn.Conv2d(16, 32, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(32),
        nn.MaxPool2d(2, 2), nn.Dropout2d(0.1),
    )
    self.first_process = nn.ModuleList(
        ResBlock(32) for i in range(16)
    )
    self.reshape = nn.Sequential(
        nn.Conv2d(32, 64, 3, padding=1), nn.PReLU(), nn.BatchNorm2d(64), nn.MaxPool2d(2, 2)
    )
    self.second_process = nn.ModuleList(
        ResBlock(64) for i in range(16)
    )
    self.prelinear = nn.Sequential(
        nn.AdaptiveAvgPool2d((4, 4)), nn.Flatten(1),
    )
    self.linears = nn.ModuleList(
        [nn.Sequential(nn.Linear(4 * 4 * 4, 8), nn.PReLU(), nn.Dropout(0.1)) for i in range(16)]
    )
    self.meta = nn.Sequential(
        Meta(16, 8), nn.PReLU(),
    )
    self.out = nn.Linear(64, 10)

  def forward(self, batch):
    prepared_batch = self.input_filter(batch)
    for block in self.first_process:
      prepared_batch = block(prepared_batch)

    reshaped_batch = self.reshape(prepared_batch)
    for block in self.second_process:
      reshaped_batch = block(reshaped_batch)
    output_batch = self.prelinear(reshaped_batch)
    temp = []
    for i, linear in enumerate(self.linears):
      temp.append(linear(output_batch[:, i*output_batch.shape[1]//16 : (i+1)*output_batch.shape[1]//16]).unsqueeze(-1))
    output_batch = torch.cat(temp, axis=-1)
    output_batch = self.meta(output_batch)
    output_batch = output_batch.flatten(1)

    return self.out(output_batch)

# %%
net = MyNet_Meta_linear_3().to(device)
criterion = torch.nn.CrossEntropyLoss()
metric = torchmetrics.Accuracy().to(device)
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# %%
summary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#              PReLU-2           [-1, 16, 32, 32]               1
#        BatchNorm2d-3           [-1, 16, 32, 32]              32
#             Conv2d-4           [-1, 32, 32, 32]           4,640
#              PReLU-5           [-1, 32, 32, 32]               1
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#          MaxPool2d-7           [-1, 32, 16, 16]               0
#          Dropout2d-8           [-1, 32, 16, 16]               0
#             Conv2d-9           [-1, 32, 16, 16]           9,248
#             PReLU-10           [-1, 32, 16, 16]               1
#       BatchNorm2d-11           [-1, 32, 16, 16]              64
#            Conv2d-12           [-1, 32, 16, 16]           9,248
#             PReLU-13           [-1, 32, 16, 16]               1
#       BatchNorm2d-14           [-1, 32, 16, 16]              64
#         Dropout2d-15           [-1, 32, 16, 16]               0
#           ResUnit-16           [-1, 32, 16, 16]               0
#          ResBlock-17           [-1, 32, 16, 16]               0
#            Conv2d-18           [-1, 32, 16, 16]           9,248
#             PReLU-19           [-1, 32, 16, 16]               1
#       BatchNorm2d-20           [-1, 32, 16, 16]              64
#            Conv2d-21           [-1, 32, 16, 16]           9,248
#             PReLU-22           [-1, 32, 16, 16]               1
#       BatchNorm2d-23           [-1, 32, 16, 16]              64
#         Dropout2d-24           [-1, 32, 16, 16]               0
#           ResUnit-25           [-1, 32, 16, 16]               0
#          ResBlock-26           [-1, 32, 16, 16]               0
#            Conv2d-27           [-1, 32, 16, 16]           9,248
#             PReLU-28           [-1, 32, 16, 16]               1
#       BatchNorm2d-29           [-1, 32, 16, 16]              64
#            Conv2d-30           [-1, 32, 16, 16]           9,248
#             PReLU-31           [-1, 32, 16, 16]               1
#       BatchNorm2d-32           [-1, 32, 16, 16]              64
#         Dropout2d-33           [-1, 32, 16, 16]               0
#           ResUnit-34           [-1, 32, 16, 16]               0
#          ResBlock-35           [-1, 32, 16, 16]               0
#            Conv2d-36           [-1, 32, 16, 16]           9,248
#             PReLU-37           [-1, 32, 16, 16]               1
#       BatchNorm2d-38           [-1, 32, 16, 16]              64
#            Conv2d-39           [-1, 32, 16, 16]           9,248
#             PReLU-40           [-1, 32, 16, 16]               1
#       BatchNorm2d-41           [-1, 32, 16, 16]              64
#         Dropout2d-42           [-1, 32, 16, 16]               0
#           ResUnit-43           [-1, 32, 16, 16]               0
#          ResBlock-44           [-1, 32, 16, 16]               0
#            Conv2d-45           [-1, 32, 16, 16]           9,248
#             PReLU-46           [-1, 32, 16, 16]               1
#       BatchNorm2d-47           [-1, 32, 16, 16]              64
#            Conv2d-48           [-1, 32, 16, 16]           9,248
#             PReLU-49           [-1, 32, 16, 16]               1
#       BatchNorm2d-50           [-1, 32, 16, 16]              64
#         Dropout2d-51           [-1, 32, 16, 16]               0
#           ResUnit-52           [-1, 32, 16, 16]               0
#          ResBlock-53           [-1, 32, 16, 16]               0
#            Conv2d-54           [-1, 32, 16, 16]           9,248
#             PReLU-55           [-1, 32, 16, 16]               1
#       BatchNorm2d-56           [-1, 32, 16, 16]              64
#            Conv2d-57           [-1, 32, 16, 16]           9,248
#             PReLU-58           [-1, 32, 16, 16]               1
#       BatchNorm2d-59           [-1, 32, 16, 16]              64
#         Dropout2d-60           [-1, 32, 16, 16]               0
#           ResUnit-61           [-1, 32, 16, 16]               0
#          ResBlock-62           [-1, 32, 16, 16]               0
#            Conv2d-63           [-1, 32, 16, 16]           9,248
#             PReLU-64           [-1, 32, 16, 16]               1
#       BatchNorm2d-65           [-1, 32, 16, 16]              64
#            Conv2d-66           [-1, 32, 16, 16]           9,248
#             PReLU-67           [-1, 32, 16, 16]               1
#       BatchNorm2d-68           [-1, 32, 16, 16]              64
#         Dropout2d-69           [-1, 32, 16, 16]               0
#           ResUnit-70           [-1, 32, 16, 16]               0
#          ResBlock-71           [-1, 32, 16, 16]               0
#            Conv2d-72           [-1, 32, 16, 16]           9,248
#             PReLU-73           [-1, 32, 16, 16]               1
#       BatchNorm2d-74           [-1, 32, 16, 16]              64
#            Conv2d-75           [-1, 32, 16, 16]           9,248
#             PReLU-76           [-1, 32, 16, 16]               1
#       BatchNorm2d-77           [-1, 32, 16, 16]              64
#         Dropout2d-78           [-1, 32, 16, 16]               0
#           ResUnit-79           [-1, 32, 16, 16]               0
#          ResBlock-80           [-1, 32, 16, 16]               0
#            Conv2d-81           [-1, 32, 16, 16]           9,248
#             PReLU-82           [-1, 32, 16, 16]               1
#       BatchNorm2d-83           [-1, 32, 16, 16]              64
#            Conv2d-84           [-1, 32, 16, 16]           9,248
#             PReLU-85           [-1, 32, 16, 16]               1
#       BatchNorm2d-86           [-1, 32, 16, 16]              64
#         Dropout2d-87           [-1, 32, 16, 16]               0
#           ResUnit-88           [-1, 32, 16, 16]               0
#          ResBlock-89           [-1, 32, 16, 16]               0
#            Conv2d-90           [-1, 32, 16, 16]           9,248
#             PReLU-91           [-1, 32, 16, 16]               1
#       BatchNorm2d-92           [-1, 32, 16, 16]              64
#            Conv2d-93           [-1, 32, 16, 16]           9,248
#             PReLU-94           [-1, 32, 16, 16]               1
#       BatchNorm2d-95           [-1, 32, 16, 16]              64
#         Dropout2d-96           [-1, 32, 16, 16]               0
#           ResUnit-97           [-1, 32, 16, 16]               0
#          ResBlock-98           [-1, 32, 16, 16]               0
#            Conv2d-99           [-1, 32, 16, 16]           9,248
#            PReLU-100           [-1, 32, 16, 16]               1
#      BatchNorm2d-101           [-1, 32, 16, 16]              64
#           Conv2d-102           [-1, 32, 16, 16]           9,248
#            PReLU-103           [-1, 32, 16, 16]               1
#      BatchNorm2d-104           [-1, 32, 16, 16]              64
#        Dropout2d-105           [-1, 32, 16, 16]               0
#          ResUnit-106           [-1, 32, 16, 16]               0
#         ResBlock-107           [-1, 32, 16, 16]               0
#           Conv2d-108           [-1, 32, 16, 16]           9,248
#            PReLU-109           [-1, 32, 16, 16]               1
#      BatchNorm2d-110           [-1, 32, 16, 16]              64
#           Conv2d-111           [-1, 32, 16, 16]           9,248
#            PReLU-112           [-1, 32, 16, 16]               1
#      BatchNorm2d-113           [-1, 32, 16, 16]              64
#        Dropout2d-114           [-1, 32, 16, 16]               0
#          ResUnit-115           [-1, 32, 16, 16]               0
#         ResBlock-116           [-1, 32, 16, 16]               0
#           Conv2d-117           [-1, 32, 16, 16]           9,248
#            PReLU-118           [-1, 32, 16, 16]               1
#      BatchNorm2d-119           [-1, 32, 16, 16]              64
#           Conv2d-120           [-1, 32, 16, 16]           9,248
#            PReLU-121           [-1, 32, 16, 16]               1
#      BatchNorm2d-122           [-1, 32, 16, 16]              64
#        Dropout2d-123           [-1, 32, 16, 16]               0
#          ResUnit-124           [-1, 32, 16, 16]               0
#         ResBlock-125           [-1, 32, 16, 16]               0
#           Conv2d-126           [-1, 32, 16, 16]           9,248
#            PReLU-127           [-1, 32, 16, 16]               1
#      BatchNorm2d-128           [-1, 32, 16, 16]              64
#           Conv2d-129           [-1, 32, 16, 16]           9,248
#            PReLU-130           [-1, 32, 16, 16]               1
#      BatchNorm2d-131           [-1, 32, 16, 16]              64
#        Dropout2d-132           [-1, 32, 16, 16]               0
#          ResUnit-133           [-1, 32, 16, 16]               0
#         ResBlock-134           [-1, 32, 16, 16]               0
#           Conv2d-135           [-1, 32, 16, 16]           9,248
#            PReLU-136           [-1, 32, 16, 16]               1
#      BatchNorm2d-137           [-1, 32, 16, 16]              64
#           Conv2d-138           [-1, 32, 16, 16]           9,248
#            PReLU-139           [-1, 32, 16, 16]               1
#      BatchNorm2d-140           [-1, 32, 16, 16]              64
#        Dropout2d-141           [-1, 32, 16, 16]               0
#          ResUnit-142           [-1, 32, 16, 16]               0
#         ResBlock-143           [-1, 32, 16, 16]               0
#           Conv2d-144           [-1, 32, 16, 16]           9,248
#            PReLU-145           [-1, 32, 16, 16]               1
#      BatchNorm2d-146           [-1, 32, 16, 16]              64
#           Conv2d-147           [-1, 32, 16, 16]           9,248
#            PReLU-148           [-1, 32, 16, 16]               1
#      BatchNorm2d-149           [-1, 32, 16, 16]              64
#        Dropout2d-150           [-1, 32, 16, 16]               0
#          ResUnit-151           [-1, 32, 16, 16]               0
#         ResBlock-152           [-1, 32, 16, 16]               0
#           Conv2d-153           [-1, 64, 16, 16]          18,496
#            PReLU-154           [-1, 64, 16, 16]               1
#      BatchNorm2d-155           [-1, 64, 16, 16]             128
#        MaxPool2d-156             [-1, 64, 8, 8]               0
#           Conv2d-157             [-1, 64, 8, 8]          36,928
#            PReLU-158             [-1, 64, 8, 8]               1
#      BatchNorm2d-159             [-1, 64, 8, 8]             128
#           Conv2d-160             [-1, 64, 8, 8]          36,928
#            PReLU-161             [-1, 64, 8, 8]               1
#      BatchNorm2d-162             [-1, 64, 8, 8]             128
#        Dropout2d-163             [-1, 64, 8, 8]               0
#          ResUnit-164             [-1, 64, 8, 8]               0
#         ResBlock-165             [-1, 64, 8, 8]               0
#           Conv2d-166             [-1, 64, 8, 8]          36,928
#            PReLU-167             [-1, 64, 8, 8]               1
#      BatchNorm2d-168             [-1, 64, 8, 8]             128
#           Conv2d-169             [-1, 64, 8, 8]          36,928
#            PReLU-170             [-1, 64, 8, 8]               1
#      BatchNorm2d-171             [-1, 64, 8, 8]             128
#        Dropout2d-172             [-1, 64, 8, 8]               0
#          ResUnit-173             [-1, 64, 8, 8]               0
#         ResBlock-174             [-1, 64, 8, 8]               0
#           Conv2d-175             [-1, 64, 8, 8]          36,928
#            PReLU-176             [-1, 64, 8, 8]               1
#      BatchNorm2d-177             [-1, 64, 8, 8]             128
#           Conv2d-178             [-1, 64, 8, 8]          36,928
#            PReLU-179             [-1, 64, 8, 8]               1
#      BatchNorm2d-180             [-1, 64, 8, 8]             128
#        Dropout2d-181             [-1, 64, 8, 8]               0
#          ResUnit-182             [-1, 64, 8, 8]               0
#         ResBlock-183             [-1, 64, 8, 8]               0
#           Conv2d-184             [-1, 64, 8, 8]          36,928
#            PReLU-185             [-1, 64, 8, 8]               1
#      BatchNorm2d-186             [-1, 64, 8, 8]             128
#           Conv2d-187             [-1, 64, 8, 8]          36,928
#            PReLU-188             [-1, 64, 8, 8]               1
#      BatchNorm2d-189             [-1, 64, 8, 8]             128
#        Dropout2d-190             [-1, 64, 8, 8]               0
#          ResUnit-191             [-1, 64, 8, 8]               0
#         ResBlock-192             [-1, 64, 8, 8]               0
#           Conv2d-193             [-1, 64, 8, 8]          36,928
#            PReLU-194             [-1, 64, 8, 8]               1
#      BatchNorm2d-195             [-1, 64, 8, 8]             128
#           Conv2d-196             [-1, 64, 8, 8]          36,928
#            PReLU-197             [-1, 64, 8, 8]               1
#      BatchNorm2d-198             [-1, 64, 8, 8]             128
#        Dropout2d-199             [-1, 64, 8, 8]               0
#          ResUnit-200             [-1, 64, 8, 8]               0
#         ResBlock-201             [-1, 64, 8, 8]               0
#           Conv2d-202             [-1, 64, 8, 8]          36,928
#            PReLU-203             [-1, 64, 8, 8]               1
#      BatchNorm2d-204             [-1, 64, 8, 8]             128
#           Conv2d-205             [-1, 64, 8, 8]          36,928
#            PReLU-206             [-1, 64, 8, 8]               1
#      BatchNorm2d-207             [-1, 64, 8, 8]             128
#        Dropout2d-208             [-1, 64, 8, 8]               0
#          ResUnit-209             [-1, 64, 8, 8]               0
#         ResBlock-210             [-1, 64, 8, 8]               0
#           Conv2d-211             [-1, 64, 8, 8]          36,928
#            PReLU-212             [-1, 64, 8, 8]               1
#      BatchNorm2d-213             [-1, 64, 8, 8]             128
#           Conv2d-214             [-1, 64, 8, 8]          36,928
#            PReLU-215             [-1, 64, 8, 8]               1
#      BatchNorm2d-216             [-1, 64, 8, 8]             128
#        Dropout2d-217             [-1, 64, 8, 8]               0
#          ResUnit-218             [-1, 64, 8, 8]               0
#         ResBlock-219             [-1, 64, 8, 8]               0
#           Conv2d-220             [-1, 64, 8, 8]          36,928
#            PReLU-221             [-1, 64, 8, 8]               1
#      BatchNorm2d-222             [-1, 64, 8, 8]             128
#           Conv2d-223             [-1, 64, 8, 8]          36,928
#            PReLU-224             [-1, 64, 8, 8]               1
#      BatchNorm2d-225             [-1, 64, 8, 8]             128
#        Dropout2d-226             [-1, 64, 8, 8]               0
#          ResUnit-227             [-1, 64, 8, 8]               0
#         ResBlock-228             [-1, 64, 8, 8]               0
#           Conv2d-229             [-1, 64, 8, 8]          36,928
#            PReLU-230             [-1, 64, 8, 8]               1
#      BatchNorm2d-231             [-1, 64, 8, 8]             128
#           Conv2d-232             [-1, 64, 8, 8]          36,928
#            PReLU-233             [-1, 64, 8, 8]               1
#      BatchNorm2d-234             [-1, 64, 8, 8]             128
#        Dropout2d-235             [-1, 64, 8, 8]               0
#          ResUnit-236             [-1, 64, 8, 8]               0
#         ResBlock-237             [-1, 64, 8, 8]               0
#           Conv2d-238             [-1, 64, 8, 8]          36,928
#            PReLU-239             [-1, 64, 8, 8]               1
#      BatchNorm2d-240             [-1, 64, 8, 8]             128
#           Conv2d-241             [-1, 64, 8, 8]          36,928
#            PReLU-242             [-1, 64, 8, 8]               1
#      BatchNorm2d-243             [-1, 64, 8, 8]             128
#        Dropout2d-244             [-1, 64, 8, 8]               0
#          ResUnit-245             [-1, 64, 8, 8]               0
#         ResBlock-246             [-1, 64, 8, 8]               0
#           Conv2d-247             [-1, 64, 8, 8]          36,928
#            PReLU-248             [-1, 64, 8, 8]               1
#      BatchNorm2d-249             [-1, 64, 8, 8]             128
#           Conv2d-250             [-1, 64, 8, 8]          36,928
#            PReLU-251             [-1, 64, 8, 8]               1
#      BatchNorm2d-252             [-1, 64, 8, 8]             128
#        Dropout2d-253             [-1, 64, 8, 8]               0
#          ResUnit-254             [-1, 64, 8, 8]               0
#         ResBlock-255             [-1, 64, 8, 8]               0
#           Conv2d-256             [-1, 64, 8, 8]          36,928
#            PReLU-257             [-1, 64, 8, 8]               1
#      BatchNorm2d-258             [-1, 64, 8, 8]             128
#           Conv2d-259             [-1, 64, 8, 8]          36,928
#            PReLU-260             [-1, 64, 8, 8]               1
#      BatchNorm2d-261             [-1, 64, 8, 8]             128
#        Dropout2d-262             [-1, 64, 8, 8]               0
#          ResUnit-263             [-1, 64, 8, 8]               0
#         ResBlock-264             [-1, 64, 8, 8]               0
#           Conv2d-265             [-1, 64, 8, 8]          36,928
#            PReLU-266             [-1, 64, 8, 8]               1
#      BatchNorm2d-267             [-1, 64, 8, 8]             128
#           Conv2d-268             [-1, 64, 8, 8]          36,928
#            PReLU-269             [-1, 64, 8, 8]               1
#      BatchNorm2d-270             [-1, 64, 8, 8]             128
#        Dropout2d-271             [-1, 64, 8, 8]               0
#          ResUnit-272             [-1, 64, 8, 8]               0
#         ResBlock-273             [-1, 64, 8, 8]               0
#           Conv2d-274             [-1, 64, 8, 8]          36,928
#            PReLU-275             [-1, 64, 8, 8]               1
#      BatchNorm2d-276             [-1, 64, 8, 8]             128
#           Conv2d-277             [-1, 64, 8, 8]          36,928
#            PReLU-278             [-1, 64, 8, 8]               1
#      BatchNorm2d-279             [-1, 64, 8, 8]             128
#        Dropout2d-280             [-1, 64, 8, 8]               0
#          ResUnit-281             [-1, 64, 8, 8]               0
#         ResBlock-282             [-1, 64, 8, 8]               0
#           Conv2d-283             [-1, 64, 8, 8]          36,928
#            PReLU-284             [-1, 64, 8, 8]               1
#      BatchNorm2d-285             [-1, 64, 8, 8]             128
#           Conv2d-286             [-1, 64, 8, 8]          36,928
#            PReLU-287             [-1, 64, 8, 8]               1
#      BatchNorm2d-288             [-1, 64, 8, 8]             128
#        Dropout2d-289             [-1, 64, 8, 8]               0
#          ResUnit-290             [-1, 64, 8, 8]               0
#         ResBlock-291             [-1, 64, 8, 8]               0
#           Conv2d-292             [-1, 64, 8, 8]          36,928
#            PReLU-293             [-1, 64, 8, 8]               1
#      BatchNorm2d-294             [-1, 64, 8, 8]             128
#           Conv2d-295             [-1, 64, 8, 8]          36,928
#            PReLU-296             [-1, 64, 8, 8]               1
#      BatchNorm2d-297             [-1, 64, 8, 8]             128
#        Dropout2d-298             [-1, 64, 8, 8]               0
#          ResUnit-299             [-1, 64, 8, 8]               0
#         ResBlock-300             [-1, 64, 8, 8]               0
# AdaptiveAvgPool2d-301             [-1, 64, 4, 4]               0
#          Flatten-302                 [-1, 1024]               0
#           Linear-303                    [-1, 8]             520
#            PReLU-304                    [-1, 8]               1
#          Dropout-305                    [-1, 8]               0
#           Linear-306                    [-1, 8]             520
#            PReLU-307                    [-1, 8]               1
#          Dropout-308                    [-1, 8]               0
#           Linear-309                    [-1, 8]             520
#            PReLU-310                    [-1, 8]               1
#          Dropout-311                    [-1, 8]               0
#           Linear-312                    [-1, 8]             520
#            PReLU-313                    [-1, 8]               1
#          Dropout-314                    [-1, 8]               0
#           Linear-315                    [-1, 8]             520
#            PReLU-316                    [-1, 8]               1
#          Dropout-317                    [-1, 8]               0
#           Linear-318                    [-1, 8]             520
#            PReLU-319                    [-1, 8]               1
#          Dropout-320                    [-1, 8]               0
#           Linear-321                    [-1, 8]             520
#            PReLU-322                    [-1, 8]               1
#          Dropout-323                    [-1, 8]               0
#           Linear-324                    [-1, 8]             520
#            PReLU-325                    [-1, 8]               1
#          Dropout-326                    [-1, 8]               0
#           Linear-327                    [-1, 8]             520
#            PReLU-328                    [-1, 8]               1
#          Dropout-329                    [-1, 8]               0
#           Linear-330                    [-1, 8]             520
#            PReLU-331                    [-1, 8]               1
#          Dropout-332                    [-1, 8]               0
#           Linear-333                    [-1, 8]             520
#            PReLU-334                    [-1, 8]               1
#          Dropout-335                    [-1, 8]               0
#           Linear-336                    [-1, 8]             520
#            PReLU-337                    [-1, 8]               1
#          Dropout-338                    [-1, 8]               0
#           Linear-339                    [-1, 8]             520
#            PReLU-340                    [-1, 8]               1
#          Dropout-341                    [-1, 8]               0
#           Linear-342                    [-1, 8]             520
#            PReLU-343                    [-1, 8]               1
#          Dropout-344                    [-1, 8]               0
#           Linear-345                    [-1, 8]             520
#            PReLU-346                    [-1, 8]               1
#          Dropout-347                    [-1, 8]               0
#           Linear-348                    [-1, 8]             520
#            PReLU-349                    [-1, 8]               1
#          Dropout-350                    [-1, 8]               0
#             Meta-351                 [-1, 8, 8]             128
#            PReLU-352                 [-1, 8, 8]               1
#           Linear-353                   [-1, 10]             650
# ================================================================
# Total params: 1,516,766
# Trainable params: 1,516,766
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 15.18
# Params size (MB): 5.79
# Estimated Total Size (MB): 20.97
# ----------------------------------------------------------------

# %%
epochs = 20
history_loss, history_metrics, history_test_loss, history_test_metrics = train(net, trainloader, testloader, optimizer, criterion, metric, epochs=epochs)

print("Обучение завершено")
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].set_title("Losses")
ax[0].plot(history_loss, label="train")
ax[0].plot(history_test_loss, label="test")
ax[0].legend()
ax[0].hlines(np.linspace(0, np.max(history_test_loss), epochs), xmin=0, xmax=epochs-1, colors='black', alpha=0.3, linestyles="--", lw=0.5)

ax[1].set_title("Accuracy")
ax[1].plot(history_metrics, label="train")
ax[1].plot(history_test_metrics, label="test")
ax[1].legend()
ax[1].hlines(np.linspace(0, 1, 10), xmin=0, xmax=epochs-1, colors='black', alpha=0.3, linestyles="--", lw=0.5)

print("Best accuracy:",  np.max(history_test_metrics))
plt.show()
# Out:
# Обучение завершено
# Best accuracy: 0.8426621835443038
